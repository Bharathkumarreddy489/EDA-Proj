# %%
#importing required Liabraries
import pandas as pd
import seaborn as sns
import numpy as np

# %%
#loading the dataset
df=pd.read_csv("BlackFriday.csv")

# %%
#displaying the first five rows of dataset
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
#information regarding the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
#all the columns and number of unique values in each column
for col in df.columns:
    print(col,":",df[col].nunique())
# Out:
# User_ID : 5891
# Product_ID : 3623
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category_1 : 18
# Product_Category_2 : 17
# Product_Category_3 : 15
# Purchase : 17959

# %%
#describing about dataset
df.describe()
# Out:
#             User_ID    Occupation  Marital_Status  Product_Category_1  \
# count  5.375770e+05  537577.00000   537577.000000       537577.000000
# mean   1.002992e+06       8.08271        0.408797            5.295546
# std    1.714393e+03       6.52412        0.491612            3.750701
# min    1.000001e+06       0.00000        0.000000            1.000000
# 25%    1.001495e+06       2.00000        0.000000            1.000000
# 50%    1.003031e+06       7.00000        0.000000            5.000000
# 75%    1.004417e+06      14.00000        1.000000            8.000000
# max    1.006040e+06      20.00000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       370591.000000       164278.000000  537577.000000
# mean             9.842144           12.669840    9333.859853
# std              5.087259            4.124341    4981.022133
# min              2.000000            3.000000     185.000000
# ...

# %%
#checking the null values count in dataset
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
#dropping or deleting the null values
del df['Product_Category_2']
del df['Product_Category_3']

# %%
#again checking the null values are removed or not
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# dtype: int64

# %%
#analyzing the each and every column
#number of unique users are
df['User_ID'].nunique()
# Out:
# 5891

# %%
#user id of all unique users are
df['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %%
#number of unique products are
df['Product_ID'].nunique()
# Out:
# 3623

# %%
#available genders are
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
#range of age
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
#total unique occupations are
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
#unique city categories
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
#range of stay in current city for how many years
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
#checking the martial status
df['Marital_Status'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
#product category-1 types
df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
#mean purchase is
df['Purchase'].sum()/len(df['Purchase'])
# Out:
# 9333.859852635065

# %%
#total number of unique values in  each and evry column
for column in df.columns:
    print(column,":",df[column].nunique())
# Out:
# User_ID : 5891
# Product_ID : 3623
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category_1 : 18
# Purchase : 17959

# %%
#total number of males and females
data=pd.DataFrame({'Ratio':[len(df[df['Gender'] =='M']),len(df[df['Gender'] =='F'])]},index=['Male','Female'])
data
# Out:
#          Ratio
# Male    405380
# Female  132197

# %%
#univariate analysis of gender and plotting bar graph
data.plot(kind='bar',title='Gender Ratio')
# Out:
# <AxesSubplot:title={'center':'Gender Ratio'}>

# %%
#analyzing the gender and plotting the pie graph
#data=pd.DataFrame({'Ratio':[len(df[df['Gender'] =='M']),len(df[df['Gender'] =='F'])]},index=['Male','Female'])
data.plot.pie(y='Ratio',figsize=(6,6),autopct='%.2f' )
# Out:
# <AxesSubplot:ylabel='Ratio'>

# %%
#plotting the pie graph of city category
df.groupby('City_Category').size().plot(kind='pie',autopct='%0.1f',title='City_Category')
# Out:
# <AxesSubplot:title={'center':'City_Category'}, ylabel='None'>

# %%
#univariate Analysis of Purchase Column
#lower whisker value = 185 , higher whisker value = 23961 and median = 8062.0
#inter quartile range apprx 6000 to 13000
sns.boxplot(y=df['Purchase'])
# Out:
# <AxesSubplot:ylabel='Purchase'>

# %%
#plotting the graph of martial status
df.groupby("Marital_Status").size().plot(kind='pie',autopct='%.1f',title="Marital_Status")
# Out:
# <AxesSubplot:title={'center':'Marital_Status'}, ylabel='None'>

# %%
#plotting the graph of occupation
df.groupby("Occupation").size().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Occupation'>

# %%
#plotting the graph of stay in current city year
df.groupby("Stay_In_Current_City_Years").size().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years'>

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'])
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
#purchase Distribution by age
df.groupby("Age").size().plot(kind='bar',figsize=(12,6),title='Purchase Distribution by Age')
# Out:
# <AxesSubplot:title={'center':'Purchase Distribution by Age'}, xlabel='Age'>

# %%
#number ofproducts purchased by certain age
for i in df['Age'].unique():
    print(i,":",len(df[df['Age']==i]))
# Out:
# 0-17 : 14707
# 55+ : 20903
# 26-35 : 214690
# 46-50 : 44526
# 51-55 : 37618
# 36-45 : 107499
# 18-25 : 97634

# %%
#plotting the graph of number of products purchased by certain age
lst=[]
for i in df['Age'].unique():
    lst.append([i,df[df['Age']==i]['Product_ID'].nunique()])
data=pd.DataFrame(lst,columns=['Age','Products'])
data.plot(kind='bar',x='Age',title='products purchsed by certain age')
# Out:
# <AxesSubplot:title={'center':'products purchsed by certain age'}, xlabel='Age'>

# %%
#percentage of purchase done by male and females
df.groupby("Gender").sum()["Purchase"].plot(kind='pie',autopct='%.1f',title='percentage of purchase done by male and females')
# Out:
# <AxesSubplot:title={'center':'percentage of purchase done by male and females'}, ylabel='Purchase'>

# %%
#first 10 largest quantity product Id's
df.groupby('Product_ID').size().nlargest(10).sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Product_ID'>

# %%
#multicolumn analysis
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x='Age',hue='Gender',data=df).set(title='Age and Gender Analysis')
# Out:
# [Text(0.5, 1.0, 'Age and Gender Analysis')]

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x='Gender',hue='Age',data=df).set(title='Gender and Age Analysis')
# Out:
# [Text(0.5, 1.0, 'Gender and Age Analysis')]

# %%
#gender and martial status analysis
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x='Gender',hue='Marital_Status',data=df).set(title='Gender and Martial Status analysis')
# Out:
# [Text(0.5, 1.0, 'Gender and Martial Status analysis')]

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x='Marital_Status',hue='Gender',data=df).set(title='Martial Status and Gender Analysis')
# Out:
# [Text(0.5, 1.0, 'Martial Status and Gender Analysis')]

# %%
#city category and age analysis
sns.countplot(x='City_Category',hue='Age',data=df).set(title='City Category and Age analysis')
# Out:
# [Text(0.5, 1.0, 'City Category and Age analysis')]

# %%
sns.countplot(x='Age',hue='City_Category',data=df).set(title='Age and City Category Analysis')
# Out:
# [Text(0.5, 1.0, 'Age and City Category Analysis')]

# %%
#Martial Status and City Category Analysis
sns.countplot(x='Marital_Status',hue='City_Category',data=df).set(title='Martial Status and City Category Analysis')
# Out:
# [Text(0.5, 1.0, 'Martial Status and City Category Analysis')]

# %%
#City Category and Gender Analysis
sns.countplot(x='City_Category',hue='Gender',data=df).set(title='City Category and Gender Analysis')
# Out:
# [Text(0.5, 1.0, 'City Category and Gender Analysis')]

# %%
#Stay In Current City Years and Gender Analysis
sns.countplot(x='Stay_In_Current_City_Years',hue='Gender',data=df).set(title='Stay In Current City Years and Gender Analysis')
# Out:
# [Text(0.5, 1.0, 'Stay In Current City Years and Gender Analysis')]

# %%
#Stay In Current City Years and Martial Status Analysis
sns.countplot(x='Stay_In_Current_City_Years',hue='Marital_Status',data=df).set(title='Stay In Current City Years and Martial Status Analysis')
# Out:
# [Text(0.5, 1.0, 'Stay In Current City Years and Martial Status Analysis')]

# %%
#combining gender and marital status
l=[]
for i in range(len(df)):
    l.append(df['Gender'][i]+"_"+str(df['Marital_Status'][i]))
df['MaritalGender']=l

# %%
sns.countplot(x=df['MaritalGender']).set(title='MartialGender')
# Out:
# [Text(0.5, 1.0, 'MartialGender')]

# %%
#City Category and MartialGender Analysis
sns.countplot(x=df['City_Category'],hue=df['MaritalGender']).set(title='City Category and MartialGender Analysis')
# Out:
# [Text(0.5, 1.0, 'City Category and MartialGender Analysis')]

# %%
#Age and Martial Gender Analysis
sns.countplot(x=df['Age'],hue=df['MaritalGender']).set(title='Age and Martial Gender Analysis')
# Out:
# [Text(0.5, 1.0, 'Age and Martial Gender Analysis')]

# %%
#Stay In Current City Years and MartialGender Analyis
sns.countplot(x=df['Stay_In_Current_City_Years'],hue=df['MaritalGender']).set(title='Stay In Current City Years and MartialGender Analyis')
# Out:
# [Text(0.5, 1.0, 'Stay In Current City Years and MartialGender Analyis')]

# %%
sns.countplot(data=df,x="Gender",hue='City_Category')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>
